# %%
from plot_tools.animate_field import animate_field
import numpy as np
suffix = "output"
dir = f"diags_{suffix}/"

# %%
field_data = np.load(dir + "N_e.npy")
times = np.load(dir + "collection_times.npy")
nodes = np.load(dir + "z_nodes.npy")
ani = animate_field(field_data, times, nodes)
ani.save(f"./N_e_{suffix}.mp4", writer="ffmpeg", fps=20)

# %%
field_data = np.load(dir + "E_y.npy")
times = np.load(dir + "collection_times.npy")
nodes = np.load(dir + "z_nodes.npy")
ani = animate_field(field_data, times, nodes)
ani.save(f"./E_y_{suffix}.mp4", writer="ffmpeg", fps=20)
